# %%
import pandas as pd
import seaborn as sns
import numpy as np
import sys

df_train_original = pd.read_csv('./data/278_labelled_uri_train.csv')
df_train = df_train_original.copy()

# %%
df_train.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  duration (ms)  danceability  \
# 0        139790        139790      139790     179067.000         0.395
# 1        196225        196225      196225     392333.000         0.315
# 2        117476        117476      117476     115312.000         0.129
# 3         27767         27767       27767     149201.000         0.676
# 4         95337         95337       95337     257893.000         0.132
#
#    energy  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.336    -9.003        0.031         0.824             0.000     0.099
# 1   0.611    -6.070        0.050         0.421             0.290     0.117
# 2   0.049   -25.844        0.049         0.970             0.923     0.109
# 3   0.136   -17.745        0.084         0.984             0.925     0.110
# 4   0.098   -23.028        0.040         0.920             0.812     0.107
#
#    valence   tempo  spec_rate  labels                                   uri
# 0    0.189  94.609      0.000       0  spotify:track:75v5io8kU6Llfg2T36zhgd
# 1    0.148 146.476      0.000       0  spotify:track:1P1mhYegu7cnXphz3QQZdB
# 2    0.411 199.746      0.000       3  spotify:track:7DW0XpB02S7NiWex6tl8tN
# 3    0.189  78.227      0.000       3  spotify:track:6wmn2LNYtTowLmGG8uRNru
# 4    0.038  69.771      0.000       3  spotify:track:5mRqGsYYMs27rV43dgVmv2

# %%
display(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222350 entries, 0 to 222349
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.2      222350 non-null  int64
#  1   Unnamed: 0.1      222350 non-null  int64
#  2   Unnamed: 0        222350 non-null  int64
#  3   duration (ms)     222350 non-null  float64
#  4   danceability      222350 non-null  float64
#  5   energy            222350 non-null  float64
#  6   loudness          222350 non-null  float64
#  7   speechiness       222350 non-null  float64
#  8   acousticness      222350 non-null  float64
#  9   instrumentalness  222350 non-null  float64
#  10  liveness          222350 non-null  float64
#  11  valence           222350 non-null  float64
#  12  tempo             222350 non-null  float64
#  13  spec_rate         222350 non-null  float64
#  14  labels            222350 non-null  int64
#  15  uri               222350 non-null  object
# dtypes: float64(11), int64(4), object(1)
# memory usage: 27.1+ MB
# None

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
display(df_train.describe().T)
# Out:
#                       count       mean        std      min        25%  \
# Unnamed: 0.2     222350.000 138802.754  80221.472    0.000  69406.250
# Unnamed: 0.1     222350.000 138802.754  80221.472    0.000  69406.250
# Unnamed: 0       222350.000 138802.754  80221.472    0.000  69406.250
# duration (ms)    222350.000 232548.210 116804.787 6706.000 172000.000
# danceability     222350.000      0.552      0.189    0.000      0.432
# energy           222350.000      0.557      0.280    0.000      0.342
# loudness         222350.000    -10.366      6.675  -60.000    -12.742
# speechiness      222350.000      0.088      0.113    0.000      0.036
# acousticness     222350.000      0.387      0.365    0.000      0.034
# instrumentalness 222350.000      0.255      0.374    0.000      0.000
# liveness         222350.000      0.189      0.163    0.000      0.096
# valence          222350.000      0.449      0.268    0.000      0.220
# tempo            222350.000    119.204     30.475    0.000     95.070
# spec_rate        222350.000      0.000      0.000    0.000      0.000
# labels           222350.000      1.180      1.021    0.000      0.000
#
#                         50%        75%         max
# Unnamed: 0.2     138656.500 208263.750  277936.000
# Unnamed: 0.1     138656.500 208263.750  277936.000
# Unnamed: 0       138656.500 208263.750  277936.000
# duration (ms)    213200.000 264893.000 3919895.000
# danceability          0.571      0.693       0.989
# energy                0.591      0.793       1.000
# loudness             -8.403     -5.843       4.882
# speechiness           0.047      0.082       0.965
# acousticness          0.262      0.754       0.996
# instrumentalness      0.001      0.647       1.000
# liveness              0.121      0.227       1.000
# valence               0.434      0.665       1.000
# tempo               119.939    138.831     241.808
# spec_rate             0.000      0.000       0.000
# labels                1.000      2.000       3.000

# %%
df_train.head(5).T
# Out:
#                                                      0  \
# Unnamed: 0.2                                    139790
# Unnamed: 0.1                                    139790
# Unnamed: 0                                      139790
# duration (ms)                               179067.000
# danceability                                     0.395
# energy                                           0.336
# loudness                                        -9.003
# speechiness                                      0.031
# acousticness                                     0.824
# instrumentalness                                 0.000
# liveness                                         0.099
# valence                                          0.189
# tempo                                           94.609
# spec_rate                                        0.000
# labels                                               0
# uri               spotify:track:75v5io8kU6Llfg2T36zhgd
#
#                                                      1  \
# Unnamed: 0.2                                    196225
# Unnamed: 0.1                                    196225
# Unnamed: 0                                      196225
# duration (ms)                               392333.000
# danceability                                     0.315
# energy                                           0.611
# loudness                                        -6.070
# speechiness                                      0.050
# acousticness                                     0.421
# instrumentalness                                 0.290
# liveness                                         0.117
# valence                                          0.148
# tempo                                          146.476
# spec_rate                                        0.000
# labels                                               0
# uri               spotify:track:1P1mhYegu7cnXphz3QQZdB
#
#                                                      2  \
# Unnamed: 0.2                                    117476
# Unnamed: 0.1                                    117476
# Unnamed: 0                                      117476
# duration (ms)                               115312.000
# danceability                                     0.129
# energy                                           0.049
# loudness                                       -25.844
# speechiness                                      0.049
# acousticness                                     0.970
# instrumentalness                                 0.923
# liveness                                         0.109
# valence                                          0.411
# tempo                                          199.746
# spec_rate                                        0.000
# labels                                               3
# uri               spotify:track:7DW0XpB02S7NiWex6tl8tN
#
#                                                      3  \
# Unnamed: 0.2                                     27767
# Unnamed: 0.1                                     27767
# Unnamed: 0                                       27767
# duration (ms)                               149201.000
# danceability                                     0.676
# energy                                           0.136
# loudness                                       -17.745
# speechiness                                      0.084
# acousticness                                     0.984
# instrumentalness                                 0.925
# liveness                                         0.110
# valence                                          0.189
# tempo                                           78.227
# spec_rate                                        0.000
# labels                                               3
# uri               spotify:track:6wmn2LNYtTowLmGG8uRNru
#
#                                                      4
# Unnamed: 0.2                                     95337
# Unnamed: 0.1                                     95337
# Unnamed: 0                                       95337
# duration (ms)                               257893.000
# danceability                                     0.132
# energy                                           0.098
# loudness                                       -23.028
# speechiness                                      0.040
# acousticness                                     0.920
# instrumentalness                                 0.812
# liveness                                         0.107
# valence                                          0.038
# tempo                                           69.771
# spec_rate                                        0.000
# labels                                               3
# uri               spotify:track:5mRqGsYYMs27rV43dgVmv2

# %% [markdown]
# *Duration*: length of the song in milliseconds
# *Danecability*: how danceable
# *Energy*: how intense is the song (loud, fast, noisy = higher value)
# *Loudness*: How loud is the song
# *Speechiness*: presence of spoken words
# *Accousticness*: how acoustic the song is (non-electric, i.e. acoustic guitar)
# *Instrumentalness*: kinda opposite of speechiness
# *Liveness*: whether its a live
# *Valence*: how positive the song is
# *Tempo*: bpm
# *spec_rate*: unknown
#
# *labels*: {'sad': 0, 'happy': 1, 'energetic': 2, 'calm': 3}

# %%
df_train.loc[df_train['labels'] == 0, 'labels'] = 'sad'
df_train.loc[df_train['labels'] == 1, 'labels'] = 'happy'
df_train.loc[df_train['labels'] == 2, 'labels'] = 'energetic'
df_train.loc[df_train['labels'] == 3, 'labels'] = 'calm'

# %%
df_train['labels'].value_counts(normalize=True)
# Out:
# labels
# happy       0.383
# sad         0.295
# energetic   0.169
# calm        0.153
# Name: proportion, dtype: float64

# %%
sns.countplot(x='labels', data=df_train)
# Out:
# <Axes: xlabel='labels', ylabel='count'>

# %% [markdown]
# *danceability*
# Assumption: sad songs are less danceable than happy songs
# We use this feature? YES!

# %%
sns.displot(df_train, x="danceability", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Accousticness*
# Assumption: energetic sougs are not acoustic. Calm songs are acoustic
# We use this? YES!

# %%
sns.displot(df_train, x="acousticness", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Energy*
# Assumption: energetic songs are energetic
# We use this? YES! There is a label energetic. Best feature so far.

# %%
sns.displot(df_train, x="energy", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Loudness*
# Assumption: less loud = calm, more loud = energetic / happyWe use this? YES! There is a label energetic
# We use this? Yes, good for calm vs rest.

# %%
sns.displot(df_train, x="loudness", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Speechiness*
# Assumption: Not good to distinguish, every label can have speechy and non-speechy songs
# We use this? NO!

# %%
sns.displot(df_train, x="speechiness", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Instrumentalness*
# Assumption: Not good to distinguish, every label can have speechy and non-speechy songs
# We use this? Maybe to distinguish calm vs rest.

# %%
sns.displot(df_train, x="instrumentalness", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Liveness*
# Assumption: Every label can be live or in studio. Not good to distinguish
# We use this? No!

# %%
sns.displot(df_train, x="liveness", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Valence*
# Assumption: Big impact on sad or happy
# We use this? Yes!

# %%
sns.displot(df_train, x="valence", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Tempo*
# Assumption: Fast tempo means more energetic, slow tempo maybe calm?
# We use this? No! Every label can have fast and slow songs.

# %%
sns.displot(df_train, x="tempo", hue="labels", kind="kde", fill=True)

# %% [markdown]
# *Tempo*
# Assumption: We don't know what this is.
# We use this? No!

# %%
df_train['spec_rate'] += sys.float_info.epsilon
sns.displot(df_train, x="spec_rate", hue="labels", kind="kde", fill=True, log_scale=True)
